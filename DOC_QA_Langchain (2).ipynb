# %%
# !pip install --upgrade langchain openai -q
# !pip install unstructured -q
# !pip install unstructured[local-inference] -q
# !pip install detectron2@git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2 -q
# !apt-get install poppler-utils
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 990.3/990.3 kB 41.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 337.0/337.0 kB 21.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 378.9/378.9 kB 23.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.8/275.8 kB 16.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 kB 10.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 39.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 63.1 MB/s eta 0:00:00
# ...

# %%
# !pip install pinecone langchain_community
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.4/214.4 kB 4.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 31.7 MB/s eta 0:00:00
# ...

# %%
import os
import openai
import pinecone
from langchain.document_loaders import DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.vectorstores import Pinecone
from langchain.llms import OpenAI
from langchain.chains.question_answering import load_qa_chain

# %%
directory = '/content/data'

def load_docs(directory):
  loader = DirectoryLoader(directory)
  documents = loader.load()
  return documents

documents = load_docs(directory)
len(documents)
# Out:
# 3

# %%
def split_docs(documents, chunk_size=1000, chunk_overlap=20):
  text_splitter = RecursiveCharacterTextSplitter(chunk_size=chunk_size, chunk_overlap=chunk_overlap)
  docs = text_splitter.split_documents(documents)
  return docs

docs = split_docs(documents)
print(len(docs))
# Out:
# 12

# %%
import os
os.environ["OPENAI_API_KEY"] = "api-key-here"

# %%
# !pip install langchain_openai langchain_chroma
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.7/46.7 kB 1.9 MB/s eta 0:00:00
# ...
#   Using cached tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 581.4/581.4 kB 12.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.2/92.2 kB 10.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 44.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 7.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 4.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.9/59.9 kB 7.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.0/107.0 kB 11.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 7.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
# !pip install langchain

# %%
# !pip install langchain_openai langchain_chroma

# %%
# !pip install langchain openai chromadb langchain_openai langchain_chroma

# %%
from langchain.schema import Document
from langchain.document_loaders import DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_openai import OpenAIEmbeddings
from langchain.vectorstores import Chroma

directory = '/content/data'

def load_docs(directory):
    loader = DirectoryLoader(directory)
    documents = loader.load()
    return documents

documents = load_docs(directory)
print(f"Loaded {len(documents)} documents")

def split_into_pages(documents, page_size=2000):
    pages = []
    for doc in documents:
        text = doc.page_content
        doc_name = doc.metadata.get('source', 'unknown')
        if doc_name == 'unknown':
            print(f"Document name is missing for document: {doc}")
        for i in range(0, len(text), page_size):
            page = text[i:i + page_size]
            page_doc = Document(page_content=page, metadata={'page_number': i // page_size + 1, 'document_name': doc_name})
            pages.append(page_doc)
    return pages

pages = split_into_pages(documents)
print(f"Split into {len(pages)} pages")


def split_docs(pages, chunk_size=1000, chunk_overlap=20):
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=chunk_size, chunk_overlap=chunk_overlap, add_start_index=True)
    docs = []
    for page in pages:
        splits = text_splitter.split_documents([page])
        for split in splits:
            split.metadata['page_number'] = page.metadata['page_number']
            split.metadata['document_name'] = page.metadata['document_name']
            docs.append(split)
    return docs

docs = split_docs(pages)
print(f"Split into {len(docs)} document chunks")
=
embeddings = OpenAIEmbeddings()

docs_with_embeddings = embeddings.embed_documents([doc.page_content for doc in docs])

vectorstore = Chroma.from_documents(
    documents=[doc for doc in docs],
    embedding=embeddings
)

retriever = vectorstore.as_retriever(search_type="similarity", search_kwargs={"k": 6})

query = "What are the skills of the person described in the text?"
retrieved_docs = retriever.invoke(query)

final_results = []
seen_content = set()

for doc in retrieved_docs:
    content_hash = hash(doc.page_content)
    if content_hash not in seen_content:
        seen_content.add(content_hash)
        final_results.append({
            'page_number': doc.metadata.get('page_number', 'N/A'),
            'document_name': doc.metadata.get('document_name', 'N/A'),
            'content': doc.page_content,
            'metadata': doc.metadata
        })

for result in final_results:
    print(f"Document Name: {result['document_name']}, Page Number: {result['page_number']}, Content: {result['content']}, Metadata: {result['metadata']}")
# Out:
# Loaded 3 documents
# Split into 6 pages
# Split into 12 document chunks
# Document Name: /content/data/coverletter.pdf, Page Number: 1, Content: During my tenure as a Research Assistant at the University at Buffalo, I employed large language models (LLMs) with prompt engineering to achieve a remarkable 96% accuracy in extracting synthesis and activation conditions from extensive MOF research papers. This experience honed my skills in research, data mining, and natural language processing, directly aligning with the responsibilities of the Machine Learning Engineer role. Furthermore, my work at Infor as an Associate Software Engineer (Machine Learning Engineer) involved developing an NLP system that translates natural language queries into structured SQL queries, showcasing my capability to innovate and implement AI solutions in real-world applications., Metadata: {'document_name': '/content/data/coverletter.pdf', 'page_number': 1, 'start_index': 661}
# ...
